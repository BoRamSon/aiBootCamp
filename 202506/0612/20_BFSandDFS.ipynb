# %% [markdown]
# ## 인접 행렬의 DFS, BFS

# %%
# https://wikidocs.net/206317

data = map(int , input().split())
# 문장으로 받는다. 문자을 잘라줘서 단어로 만든다.
print()

data = input().split()
n = int(data[0])
m = int(data[1])
print(n, m)


N, M = map(int , input().split())  # 문장으로 받는다. 문자을 잘라줘서 단어로 만든다.
# print(N, M)

arr = []

for i in range(N):
  # map 함수는 iterable 아직 진행이 안되서 filter, ranfe, zip 등등들은 for문 안에서 호출하거나 list로 감싸줘야 작동을 한다.
  arr.append(list(map(int, input().split())))
    
def printArray(arr, N):
  for i in range(0, N):
    print(arr[i])


printArray(arr, N)


"""
    | 0 1 2 3 4
  ---------------
  0 | 0             둘러싸고 있는 공간 상하좌우4 , 대각선 4개 방향
  1 | 0             
  2 | 0


"""
