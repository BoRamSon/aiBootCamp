# %% [markdown]
# ## 🟢 공백기 일정을 확인
# - 웹서비스
# - 웹서버
#
# = HTML / CSS / JS 에 대해서 Deep하게 배우는 시간이였습니다.
# = 6월 28일 하루만 django에 대해서 했습니다.

# %% [markdown]
# ## 🟢 branch
#
# - 6번 : HTML / CSS / JS
# - 7번 : django
