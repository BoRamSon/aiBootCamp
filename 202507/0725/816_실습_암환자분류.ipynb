# %% [markdown]
# <br><br>
#
# ---
#
# ## 🟢

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
import pickle

def loadData():
    cancer = load_breast_cancer()
    X = pd.DataFrame(cancer.data, columns=cancer.feature_names)
    y = cancer.target

    y_changed = np.where(y==0, 1, 0)

    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123, test_size=0.2,
                                                        stratify=y)

    return X_train, X_test, y_train, y_test

from keras import models, layers
def createModel():
    model = models.Sequential([
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(1, activation='sigmoid'),
    ])

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

from sklearn.preprocessing import StandardScaler
def preprocessing():
    X_train, X_test, y_train, y_test = loadData()
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled  = scaler.fit_transform(X_test)

    return X_train_scaled, X_test_scaled, y_train, y_test

def main():
    X_train, X_test, y_train, y_test = preprocessing()
    model = createModel()

    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath='암환자분류_딥러닝.keras',
            save_best_only=True,
            monitor='val_loss'
        )
    ]

    history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test),
                        callbacks=callbacks, batch_size=100)
    
    with open("암환자분류_딥러닝.bin", "wb") as file:
        pickle.dump(history.history, file)

    train_loss, train_acc = model.evaluate(X_train, y_train)
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f"훈련셋 손실값: {train_loss}, 정확도: {train_acc}")
    print(f"테스트셋 손실값: {test_loss}, 정확도: {test_acc}")

if __name__ == "__main__":
    main()
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %s [b'ept-Language: ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7\r\nPriority: u=0, i\r\nReferer: https://studio.fireb', b'e.google.com/\r\nSec-Ch-Ua: "Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";v="138"\r\nSec-', b'-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\nSec-Ch-Ua-Form-Factors: ']
# Bad pipe message: %s [b'esktop"\r\nSec-Ch-Ua-Full-Version: ']
# Bad pipe message: %s [b'38.0.7204.101"\r\nSec-Ch-Ua-Full-Ve', b'ion-List: "Not)A;Brand";v="8.0.0.0", "Chromium";v="138.0.7204.101", "Google Chrome";v="138.0.7204.101"\r\nSec-Ch-Ua', b'obile: ?0\r\nSec-Ch-Ua-Model: ""\r\nSec-Ch-Ua-Pl', b'form: "Windows"\r\nSec-Ch-Ua-Platform-Version: "19.0.0"\r\nSec-Ch-Ua-Wow64: ?0\r\nSec-Fetch-Dest: ifra']
# Bad pipe message: %s [b'\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-Site: cross-site\r\nSec-Fetch-Storage-Access: none\r\nSec-Fetch-User: ?1\r\n', b'c-User-Ip: 210.205.48.210\r\nUpgrade-Insecure-Requests: 1\r\nX-Forwarded-Host: 36513-f', b'ebase-aibootcamp-1753409116002.cluster-htdgsbmflbdmov5xrjithceibm.cloudworkstations.dev\r\nX-Goog-Workstat']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# 2025-07-25 07:59:24.597753: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-25 07:59:24.604111: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-25 07:59:24.621774: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753430364.656419    3710 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753430364.667924    3710 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753430364.690570    3710 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753430364.690606    3710 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753430364.690609    3710 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753430364.690612    3710 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-25 07:59:24.697368: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/20
# 2025-07-25 07:59:30.243843: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.7982 - loss: 0.5800 - val_accuracy: 0.9561 - val_loss: 0.3158
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9329 - loss: 0.3081 - val_accuracy: 0.9649 - val_loss: 0.1772
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9585 - loss: 0.1803 - val_accuracy: 0.9825 - val_loss: 0.1142
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9792 - loss: 0.1211 - val_accuracy: 0.9825 - val_loss: 0.0817
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9802 - loss: 0.0961 - val_accuracy: 0.9825 - val_loss: 0.0647
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9801 - loss: 0.0912 - val_accuracy: 0.9825 - val_loss: 0.0544
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9875 - loss: 0.0698 - val_accuracy: 0.9825 - val_loss: 0.0434
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9829 - loss: 0.0733 - val_accuracy: 0.9825 - val_loss: 0.0482
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9810 - loss: 0.0622 - val_accuracy: 0.9912 - val_loss: 0.0415
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9860 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0335
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9811 - loss: 0.0527 - val_accuracy: 0.9737 - val_loss: 0.0457
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9945 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0399
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9879 - loss: 0.0403 - val_accuracy: 0.9825 - val_loss: 0.0654
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9893 - loss: 0.0381 - val_accuracy: 0.9825 - val_loss: 0.0417
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9953 - loss: 0.0223 - val_accuracy: 0.9912 - val_loss: 0.0440
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9880 - loss: 0.0299 - val_accuracy: 0.9737 - val_loss: 0.0593
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9901 - loss: 0.0195 - val_accuracy: 0.9737 - val_loss: 0.0644
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9938 - loss: 0.0224 - val_accuracy: 0.9912 - val_loss: 0.0664
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9989 - loss: 0.0192 - val_accuracy: 0.9737 - val_loss: 0.0771
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9904 - loss: 0.0169 - val_accuracy: 0.9912 - val_loss: 0.0560
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9984 - loss: 0.0125
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9850 - loss: 0.0798
# 훈련셋 손실값: 0.01341150514781475, 정확도: 0.997802197933197
# 테스트셋 손실값: 0.05603405460715294, 정확도: 0.9912280440330505
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %sERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
#  [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Sa']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# Bad pipe message: %sERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 299, in dispatch_control
#     await self.process_control(msg)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 305, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#   File "/home/user/aiBootCamp/.venv/lib/python3.10/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
#  [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# Bad pipe message: %s [b'ept-Language: ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7\r\nPriority: u=0, i\r\nReferer: https://studio.fireb', b'e.google.com/\r\nSec-Ch-Ua: "Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";v="138"\r\nSec-', b'-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\nSec-Ch-Ua-Form-Factors: ']
# Bad pipe message: %s [b'esktop"\r\nSec-Ch-Ua-Full-Version: ']
# Bad pipe message: %s [b'38.0.7204.101"\r\nSec-Ch-Ua-Full-Ve', b'ion-List: "Not)A;Brand";v="8.0.0.0", "Chromium";v="138.0.7204.101", "Google Chrome";v="138.0.7204.101"\r\nSec-Ch-Ua', b'obile: ?0\r\nSec-Ch-Ua-Model: ""\r\nSec-Ch-Ua-Pl', b'form: "Windows"\r\nSec-Ch-Ua-Platform-Version: "19.0.0"\r\nSec-Ch-Ua-Wow64: ?0\r\nSec-Fetch-Dest: ifra']
# Bad pipe message: %s [b'\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-Site: cross-site\r\nSec-Fetch-Storage-Access: none\r\nSec-Fetch-User: ?1\r\n', b'c-User-Ip: 210.205.48.210\r\nUpgrade-Insecure-Requests: 1\r\nX-Forwarded-Host: 36513-f', b'ebase-aibootcamp-1753409116002.cluster-htdgsbmflbdmov5xrjithceibm.cloudworkstations.dev\r\nX-Goog-Workstat']
