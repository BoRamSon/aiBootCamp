# %% [markdown]
# <br><br>
#
# ## 🟢 차트 한글화
#
# - 차트에 한글화 지원하기
#     - 폰트를 바꿔야 합니다.

# %%
import matplotlib.pyplot as plt


# =======================================================
# 내 컴퓨터에 설치된 한글 글꼴을 알아보자!!!
import matplotlib.font_manager as fm  # 🔥 폰트 관리자
# 글꼴도 ttf방식 - true type 글꼴, 트루타입글꼴 이전에는 비트맵방식
# 글꼴을 확대하면 계단 모양이 나옴 => 백터방식전환 - true type 글꼴
# fm.fontManager.ttflist

# 폰트 목록 출력
font_list = [font.name for font in fm.fontManager.ttflist]
print(font_list)

# 폰트 결정 
plt.rcParams['font.family'] = 'Apple SD Gothic Neo'   # 반드시 한글이 되는 폰트를 사용해야 한다.
# 마이너스 부호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False


import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')
sns.pairplot(iris, hue = 'species')
plt.suptitle('Iris 데이터셋 시각화', fontsize = 16)
plt.show()
# Out:
# ['STIXSizeOneSym', 'DejaVu Sans Mono', 'cmtt10', 'STIXNonUnicode', 'DejaVu Sans Mono', 'STIXGeneral', 'DejaVu Serif', 'STIXSizeTwoSym', 'cmb10', 'DejaVu Serif', 'STIXSizeTwoSym', 'STIXSizeFourSym', 'STIXSizeFiveSym', 'cmex10', 'STIXNonUnicode', 'STIXSizeThreeSym', 'cmsy10', 'DejaVu Sans', 'cmss10', 'DejaVu Sans Display', 'cmr10', 'STIXGeneral', 'STIXNonUnicode', 'STIXSizeOneSym', 'STIXNonUnicode', 'STIXGeneral', 'DejaVu Serif Display', 'DejaVu Sans', 'DejaVu Sans', 'STIXSizeFourSym', 'DejaVu Serif', 'DejaVu Sans Mono', 'STIXGeneral', 'STIXSizeThreeSym', 'cmmi10', 'DejaVu Serif', 'DejaVu Sans', 'DejaVu Sans Mono', 'STHeiti', 'Toppan Bunkyu Midashi Gothic', 'Hannotate SC', 'Charter', 'Libian SC', 'Noto Sans Rejang', 'Times New Roman', 'Weibei TC', 'Osaka', 'Kannada Sangam MN', 'DIN Condensed', '.New York', 'Menlo', 'STIXGeneral', 'Noto Sans Warang Citi', 'Nadeem', 'Kai', 'Apple Braille', 'Times New Roman', 'Hiragino Sans', 'PT Sans', 'HanziPen SC', 'STIXSizeFourSym', 'Baskerville', 'Arial Narrow', 'System Font', 'BM Hanna 11yrs Old', 'Noto Sans Hanifi Rohingya', 'BM Hanna Air', 'Sathu', 'Noto Sans Osmanya', 'Bodoni 72 Oldstyle', 'Sinhala Sangam MN', 'Noto Serif Hmong Nyiakeng', 'Noto Sans Kannada', 'Al Bayan', '.SF Malayalam', 'Savoye LET', 'Courier New', 'Heiti TC', 'Hiragino Sans GB', 'BM Hanna Pro', 'Arial Unicode MS', 'Diwan Kufi', 'STIXSizeFiveSym', 'Al Tarikh', 'Bodoni Ornaments', 'Snell Roundhand', 'Corsiva Hebrew', 'Noto Sans Khudawadi', '.SF Camera', 'Devanagari MT', 'Geeza Pro', 'Arial Black', 'Noto Sans Ol Chiki', 'Noto Sans Coptic', '.SF Compact Rounded', 'Chalkboard SE', 'ITF Devanagari', 'PilGi', 'Noto Sans Tai Viet', 'Noto Sans Old South Arabian', 'Monaco', 'Nanum Brush Script', 'Noto Sans Linear B', 'Malayalam MN', 'Noto Sans Mongolian', 'Trebuchet MS', 'Noto Sans Manichaean', 'Tahoma', 'Noto Sans Old Persian', 'STIXIntegralsUpSm', 'Wingdings 3', 'Toppan Bunkyu Gothic', 'Bangla Sangam MN', 'STIXIntegralsUpD', 'Silom', 'STIXSizeOneSym', 'Skia', 'Toppan Bunkyu Mincho', 'Mishafi Gold', 'Noto Serif Balinese', 'Ayuthaya', 'Noto Sans Saurashtra', 'Galvji', 'Oriya Sangam MN', 'Noto Sans Mandaic', 'HeadLineA', 'Noto Sans Hanunoo', 'Gurmukhi Sangam MN', 'Bodoni 72', 'STIX Two Text', 'YuGothic', 'Hiragino Sans', 'Bangla MN', 'Geneva', 'Big Caslon', 'Courier New', 'Noto Sans Cham', 'Herculanum', 'Georgia', 'BM Kirang Haerang', 'Noto Serif Ahom', 'Noto Sans Egyptian Hieroglyphs', 'Tsukushi B Round Gothic', 'Noto Sans PhagsPa', '.SF NS Rounded', 'Hiragino Sans', 'Helvetica', 'Noto Sans Oriya', 'Apple SD Gothic Neo', 'Academy Engraved LET', 'Zapfino', 'Weibei SC', 'Comic Sans MS', 'Yuanti SC', 'Noto Sans Lepcha', 'LingWai TC', 'Arial Rounded MT Bold', 'Noto Sans Mahajani', 'Noto Sans Meroitic', 'Trebuchet MS', 'Webdings', 'Microsoft Sans Serif', 'Noto Sans Nabataean', 'Khmer Sangam MN', 'Arial', 'Noto Sans Palmyrene', 'BiauKaiHK', 'YuGothic', 'STIXIntegralsSm', 'STIX Two Math', 'Khmer MN', 'Apple Chancery', 'STIXGeneral', 'LiSong Pro', 'Trattatello', 'Arial', 'Verdana', 'Beirut', 'Trebuchet MS', 'BIZ UDMincho', 'Copperplate', 'Noto Sans Kayah Li', 'Noto Sans Miao', 'Noto Sans Samaritan', 'Apple LiSung', 'InaiMathi', 'STIXNonUnicode', 'Arial Narrow', 'PT Serif Caption', 'Georgia', 'Times New Roman', '.Keyboard', 'Noto Sans Khojki', 'Xingkai SC', 'Noto Sans Mro', 'Noto Sans Limbu', 'YuMincho', 'Thonburi', 'Noto Sans Linear A', 'Noto Sans Sharada', 'SimSong', 'BM Dohyeon', 'Apple Braille', 'Noto Sans Thaana', '.SF Armenian', 'Georgia', 'Noto Sans Cypriot', 'STIXSizeThreeSym', 'Arial', 'Noto Sans Batak', 'STIXIntegralsUp', 'Noto Sans Phoenician', 'Noto Sans Adlam', 'Noto Sans Buhid', 'STIXSizeTwoSym', 'Wingdings', '.SF Georgian', 'BM Jua', 'Noteworthy', 'Noto Sans Canadian Aboriginal', 'Noto Sans Duployan', 'Klee', 'Noto Sans Masaram Gondi', '.SF India', 'Noto Sans NKo', '.SF Numeric', 'Gurmukhi MN', 'Noto Sans Old Italic', 'Noto Sans Old North Arabian', 'Devanagari Sangam MN', 'Kohinoor Telugu', 'Rockwell', 'Noto Sans Tai Tham',  ...
