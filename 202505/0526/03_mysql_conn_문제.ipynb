# %% [markdown]
# <br><br><br><br>
#
# # 🟩 문제 풀기 1

# %% [markdown]
# ## 🟢 1. 먼저 SQL에서 빈테이블 만들기

# %%
CREATE TABLE tb_score(
					id bigint PRIMARY KEY AUTO_INCREMENT,
					sname varchar(20) NOT NULL,
					kor int NOT NULL,
					eng int NOT NULL,
					mat Int NOT NULL,
					regdate datetime
);


DROP TABLE tb_score;


INSERT INTO tb_score(sname, kor,  eng, mat, regdate)
values('홍길동', 90,90,90, now());


SELECT 
					sname, kor, eng, mat, (kor+eng+mat) AS total, 
					date_format(regdate, '%Y-%m-%d %H:%i') regdate
FROM tb_score;

# %% [markdown]
# ## 🟢 2. Python에서 MySQL 접근하여 python 코드로 control하기
#
# - <문제 풀기>
#   - 전체보기
#   - 추가 : 입력 받아서
#   - 수정
#     - update 테이블명 set 필드1='값1', 필드2='값2' where절
#   - 삭제
#     - delete from 테이블명 where id = 1
#   - 검색

# %% [markdown]
# | 함수             | 설명                         | 예시 결과                                               | 주의점               |
# | -------------- | -------------------------- | --------------------------------------------------- | ----------------- |
# | `fetchone()`   | 결과 중 \*\*한 줄(row)\*\*만 가져옴 | `(7369, 'SMITH', 800.0)`                            | 반복문에서 써야 전체 다 봄   |
# | `fetchall()`   | 결과 전체를 **리스트** 형태로 가져옴     | `[(7369, 'SMITH', 800.0), (7499, 'ALLEN', 1600.0)]` | 결과가 너무 많으면 메모리 부담 |
# | `fetchmany(n)` | 결과 중 **n개만** 가져옴           | `[(7369, 'SMITH', 800.0), (7499, 'ALLEN', 1600.0)]` | 나머지는 남아있음         |

# %%
import pymysql
import pymysql.cursors

conn = pymysql.connect(
    host="localhost",  # MySQL 서버 주소 (로컬 PC면 'localhost' 또는 '127.0.0.1')
    user="root",  # MySQL 사용자 이름 (기본은 'root')
    password="",  # MySQL 사용자 비밀번호 (여기에 실제 패스워드를 입력해야 함)
    db="mydb",  # 접속하려는 데이터베이스 이름 (예: 'mydb')
    port=3306,  # MySQL 포트 번호 (기본값 3306)
)

# 연결이 성공되었으면 다음 메시지를 출력한다.
print("접속 성공")

# 연결된 데이터베이스에서 SQL 명령을 실행할 수 있는 '커서'를 만든다.
cursor = conn.cursor()
# Out:
# 접속 성공

# %%
import pymysql.cursors
# -- ======================================================
# -- <문제 풀기>
# -- 전체보기
# -- 추가 : 입력 받아서
# -- 수정
  # -- update 테이블명 set 필드1='값1', 필드2='값2' where절
# -- 삭제
  # -- delete from 테이블명 where id = 1
# -- 검색
# -------------------------------------------------

# -- 전체보기
cursor = conn.cursor(pymysql.cursors.DictCursor)
sql = "select * from tb_score"
cursor.execute(sql)
rows = cursor.fetchall()
print("데이터 개수", len(rows))
for row in rows:
  print(row)
# Out:
# 데이터 개수 2
# {'id': 1, 'sname': '홍길동', 'kor': 90, 'eng': 90, 'mat': 90, 'regdate': datetime.datetime(2025, 5, 26, 15, 20, 22)}
# {'id': 2, 'sname': '김민지', 'kor': 55, 'eng': 78, 'mat': 97, 'regdate': datetime.datetime(2025, 5, 26, 16, 4, 56)}

# %%
# -- 추가 : 입력 받아서
sql = """
  INSERT INTO tb_score(sname, kor,  eng, mat, regdate)
  values('김민지', 55,78,12, now())
"""
cursor.execute(sql)
row = cursor.fetchone()
print(row)
conn.commit()
print("INSERT 완료")
# Out:
# None
# INSERT 완료

# %%
# -- 수정
# -- update 테이블명 set 필드1='값1', 필드2='값2' where절
# sql = """
#   UPDATE tb_score
#   SET mat = 99
#   WHERE sname = '김민지';
# """
# cursor.execute(sql)
# conn.commit()
# print("수정 완료")

# 🔥 위에 내용 보다는 값을 지정할 수 있게 사용해야합니다.

sql = """
  UPDATE tb_score
  SET mat = %s
  WHERE sname = %s
"""
cursor.execute(sql, (97, '김민지'))
conn.commit()
print("수정 완료")
# Out:
# 수정 완료

# %%
# -- 삭제 준비
  # -- delete from 테이블명 where id = 1
# 임시 데이터 먼저 넣기
sql = """
  INSERT INTO tb_score(sname, kor,  eng, mat, regdate)
  values('테스트', 11,11,11, now())
"""
cursor.execute(sql)
row = cursor.fetchone()
print(row)
conn.commit()
print("임시데이터 먼저 넣기 완료")
# Out:
# None
# 임시데이터 먼저 넣기 완료

# %%
# -- 삭제
  # -- delete from 테이블명 where id = 1
sql = """
  DELETE FROM tb_score WHERE sname = '테스트'
"""
cursor.execute(sql)
row = cursor.fetchone()
print(row)
conn.commit()
print("삭제 완료")
# Out:
# None
# 임시데이터 먼저 넣기 완료

# %%
# -- 검색

sql = """
  SELECT
    sname, kor, eng, mat, (kor+eng+mat) AS total, 
    date_format(regdate, '%Y-%m-%d %H:%i') regdate
  FROM tb_score;
"""
cursor.execute(sql)
rows = cursor.fetchall()
print("데이터 개수", len(rows))
for row in rows:
  print(row)
# Out:
# 데이터 개수 2
# {'sname': '홍길동', 'kor': 90, 'eng': 90, 'mat': 90, 'total': 270, 'regdate': '2025-05-26 15:20'}
# {'sname': '김민지', 'kor': 55, 'eng': 78, 'mat': 97, 'total': 230, 'regdate': '2025-05-26 16:04'}

# %%
# 데이터베이스 연결을 종료한다.
conn.close()

# %% [markdown]
# ## 🟢 3. 위에서 풀었던 문제를 class 로 만들기
#
# - <문제 풀기>
#   - 전체보기
#   - 추가 : 입력 받아서
#   - 수정
#     - update 테이블명 set 필드1='값1', 필드2='값2' where절
#   - 삭제
#     - delete from 테이블명 where id = 1
#   - 검색 (구현 안함)
#   - 마지막으로 메뉴로 선택할 수 있도록 하세요.

# %% [markdown]
# ### 🟡 내가 직접 풀어보기

# %%
import pymysql
import pymysql.cursors


class MysqlBasic:
    def __init__(self):
        # MySQL server에 접속하여 데이터를 조작할 수 있다.
        self.conn = self.mysql_conn()
        # 연결된 데이터베이스에서 SQL 명령을 실행할 수 있는 '커서'를 만든다.
        self.cursor = self.conn.cursor(pymysql.cursors.DictCursor)

        # - <문제 풀기>
        #   - 전체보기
        #   - 추가 : 입력 받아서
        #   - 수정
        #     - update 테이블명 set 필드1='값1', 필드2='값2' where절
        #   - 삭제
        #     - delete from 테이블명 where id = 1
        #   - 검색

    def mysql_conn(self):
        conn = pymysql.connect(
            host="localhost",  # MySQL 서버 주소 (로컬 PC면 'localhost' 또는 '127.0.0.1')
            user="root",  # MySQL 사용자 이름 (기본은 'root')
            password="",  # MySQL 사용자 비밀번호 (여기에 실제 패스워드를 입력해야 함)
            db="mydb",  # 접속하려는 데이터베이스 이름 (예: 'mydb')
            port=3306,  # MySQL 포트 번호 (기본값 3306)
        )
        # 연결이 성공되었으면 다음 메시지를 출력한다.
        print("접속 성공")

        return conn

    def all_view_data(self):
        # 1. 실행할 SQL문을 문자열로 작성한다.
        # 여기서는 tb_score 테이블의 모든 행(row)을 가져오는 SELECT 문이다.
        sql = "select * from tb_score"
        # 2. cursor를 이용해 SQL문을 실행한다.
        # self.cursor는 pymysql의 DictCursor이므로 결과가 딕셔너리로 반환된다.
        self.cursor.execute(sql)
        # 3. 실행한 SELECT 쿼리 결과를 모두 가져온다.
        # fetchall()은 조회된 모든 행을 리스트로 반환한다.
        rows = self.cursor.fetchall()
        # 4. 결과 행(row)의 개수를 출력한다.
        print("데이터 개수", len(rows))
        # 5. 가져온 각 행(row)을 하나씩 출력한다.
        # row는 딕셔너리 형태이며, 예: {'id': 1, 'sname': '홍길동', 'kor': 90, ...}
        for row in rows:
            print(row)

    def insert_data(self):
        # 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
        # input으로 입력 받기
        name = input("이름 : ")
        kor = input("국어 : ")
        eng = input("영어 : ")
        mat = input("수학 : ")
        # ----- insert example -----
        sql = """
          INSERT INTO tb_score(sname, kor,  eng, mat, regdate)
          values(%s, %s,%s,%s, now())
        """
        self.cursor.execute(
            sql, (name, kor, eng, mat)
        )  # 🔥 이렇게 해야 합니다.
        self.conn.commit()
        print("INSERT 완료")
        # insert 내역 확인
        self.cursor.execute("SELECT * FROM tb_score ORDER BY id DESC LIMIT 1")
        row = self.cursor.fetchone()
        print("방금 추가된 데이터:", row)

    def update_data(self):
        # input으로 입력 받기로 고치기
        sql = """
          UPDATE tb_score
          SET mat = %s
          WHERE sname = %s
        """
        self.cursor.execute(sql, (97, "김민지"))
        self.conn.commit()
        print("수정 완료")

    def delete_data(self):
        # input으로 입력 받기로 고치기
        # ---- 삭제 ----
        sql = """
          DELETE FROM tb_score WHERE sname = '테스트'
        """
        self.cursor.execute(sql)
        self.conn.commit()
        print("삭제 완료")
        # 전체 리스트 파악

    # def search_data(self):
    #     sql = """
    #       SELECT
    #         sname, kor, eng, mat, (kor+eng+mat) AS total,
    #         date_format(regdate, '%Y-%m-%d %H:%i') regdate
    #       FROM tb_score;
    #     """
    #     self.cursor.execute(sql)
    #     rows = self.cursor.fetchall()
    #     print("데이터 개수", len(rows))
    #     for row in rows:
    #         print(row)

    def start(self):
        while True:
            print(f"1.전체보기  |  2.추가  |  3.수정  |  4.삭제  |  0.종료")
            select = input("🔢 번호 선택: ")

            if select == "1":
                self.all_view_data()
            elif select == "2":
                self.insert_data()
            elif select == "3":
                self.update_data()
            elif select == "4":
                self.delete_data()
            elif select == "0":
                break


if __name__ == "__main__":
    m = MysqlBasic()
    m.start()

# %% [markdown]
# ### 🟡 같이 풀어보기

# %%
import pymysql
import pymysql.cursors


class MysqlBasic:
    def __init__(self):
        # MySQL server에 접속하여 데이터를 조작할 수 있다.
        self.conn = self.mysql_conn()
        # 연결된 데이터베이스에서 SQL 명령을 실행할 수 있는 '커서'를 만든다.
        self.cursor = self.conn.cursor(pymysql.cursors.DictCursor) # dict 형태로 가져오겠다!

    def mysql_conn(self):
        conn = pymysql.connect(
            host="localhost",  # MySQL 서버 주소 (로컬 PC면 'localhost' 또는 '127.0.0.1')
            user="root",  # MySQL 사용자 이름 (기본은 'root')
            password="",  # MySQL 사용자 비밀번호 (여기에 실제 패스워드를 입력해야 함)
            db="mydb",  # 접속하려는 데이터베이스 이름 (예: 'mydb')
            port=3306,  # MySQL 포트 번호 (기본값 3306)
        )
        # 연결이 성공되었으면 다음 메시지를 출력한다.
        print("접속 성공")

        return conn

    def all_view_data(self):
        # 여기는 just output
        sql = """
            SELECT
                id, sname, kor, eng, mat, 
                (kor+eng+mat) AS total,
                (kor+eng+mat)/3 AS average,
                date_format(regdate, '%Y-%m-%d %H:%i') regdate
            FROM tb_score;
        """
        print(sql)
        self.cursor.execute(sql)
        rows = self.cursor.fetchall()
        print("데이터 개수", len(rows))
        for row in rows:
            print(
                row["id"],
                row["sname"],
                row["kor"],
                row["eng"],
                row["mat"],
                row["total"],
                row["average"]
            )
        print()

    def insert_data(self):
        # 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
        # input으로 입력받기
        sname = input("이름 : ")
        kor = input("국어 : ")
        eng = input("영어 : ")
        mat = input("수학 : ")
        # ----- insert example -----
        sql = """
            INSERT INTO tb_score(sname, kor,  eng, mat, regdate)
            values(%s, %s,%s,%s, now())
        """
        self.cursor.execute(
            sql, (sname, kor, eng, mat)
        )  # 🔥 이렇게 해야합니다.
        self.conn.commit()
        print("INSERT 완료")
        # insert 내역 확인
        self.cursor.execute("SELECT * FROM tb_score ORDER BY id DESC LIMIT 1")
        row = self.cursor.fetchone()
        print("방금 추가된 데이터:", row)
        print()

    def update_data(self):
        # ---- 수정 전 전체 리스트 파악
        self.all_view_data()
        # 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
        # input으로 입력받기
        id = input("수정할 id 입력 : ")
        sname = input("이름 : ")
        kor = input("국어 : ")
        eng = input("영어 : ")
        mat = input("수학 : ")
        # ----- update example -----
        sql = """
            UPDATE tb_score
            SET 
                sname = %s,
                kor = %s,
                eng = %s,
                mat = %s
            WHERE id = %s
        """
        self.cursor.execute(
            sql, (sname, kor, eng, mat, id)
        )  # 🔥 진짜 이렇게 해야합니다.
        self.conn.commit()
        print("수정 완료")
        # ---- 수정 후 전체 리스트 파악
        self.all_view_data()
        print()

    def delete_data(self):
        # ---- 삭제 전 전체 리스트 파악
        self.all_view_data()
        # ---- 삭제 ----
        # 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
        # input으로 입력받기
        sname = input("삭제할 이름을 입력하세요 : ")
        sql = """
            DELETE FROM tb_score WHERE sname = %s
        """
        self.cursor.execute(sql, sname)
        self.conn.commit()
        print("삭제 완료")
        # ---- 삭제 후 전체 리스트 파악
        self.all_view_data()
        print()

    def start(self):
        while True:
            print(f"1.전체보기  |  2.추가  |  3.수정  |  4.삭제  |  0.종료")
            select = input("🔢 번호 선택: ")

            if select == "1":
                self.all_view_data()
            elif select == "2":
                self.insert_data()
            elif select == "3":
                self.update_data()
            elif select == "4":
                self.delete_data()
            elif select == "0":
                break

if __name__ == "__main__":
    m = MysqlBasic()
    m.start()
# Out:
# 접속 성공
# 1.전체보기  |  2.추가  |  3.수정  |  4.삭제  |  0.종료
#
#             SELECT
#                 id, sname, kor, eng, mat,
#                 (kor+eng+mat) AS total,
#                 (kor+eng+mat)/3 AS average,
#                 date_format(regdate, '%Y-%m-%d %H:%i') regdate
#             FROM tb_score;
#
# 데이터 개수 4
# 1 홍길동 90 90 90 270 90.0000
# 2 김민지 55 78 97 230 76.6667
# 4 강낭콩 22 82 34 138 46.0000
# 5 쥬만지 20 30 40 90 30.0000
#
# 수정 완료
#
#             SELECT
#                 id, sname, kor, eng, mat,
#                 (kor+eng+mat) AS total,
#                 (kor+eng+mat)/3 AS average,
#                 date_format(regdate, '%Y-%m-%d %H:%i') regdate
#             FROM tb_score;
#
# 데이터 개수 4
# 1 홍길동 90 90 90 270 90.0000
# 2 김민지 55 78 97 230 76.6667
# 4 강낭콩 22 82 34 138 46.0000
# 5 손병호 1 2 3 6 2.0000
#
#
# 1.전체보기  |  2.추가  |  3.수정  |  4.삭제  |  0.종료
#
#             SELECT
#                 id, sname, kor, eng, mat,
#                 (kor+eng+mat) AS total,
#                 (kor+eng+mat)/3 AS average,
#                 date_format(regdate, '%Y-%m-%d %H:%i') regdate
#             FROM tb_score;
#
# 데이터 개수 4
# 1 홍길동 90 90 90 270 90.0000
# 2 김민지 55 78 97 230 76.6667
# 4 강낭콩 22 82 34 138 46.0000
# 5 손병호 1 2 3 6 2.0000
#
# 삭제 완료
#
#             SELECT
#                 id, sname, kor, eng, mat,
#                 (kor+eng+mat) AS total,
#                 (kor+eng+mat)/3 AS average,
#                 date_format(regdate, '%Y-%m-%d %H:%i') regdate
#             FROM tb_score;
#
# 데이터 개수 3
# 1 홍길동 90 90 90 270 90.0000
# 2 김민지 55 78 97 230 76.6667
# 4 강낭콩 22 82 34 138 46.0000
#
#
# 1.전체보기  |  2.추가  |  3.수정  |  4.삭제  |  0.종료
