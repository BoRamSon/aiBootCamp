# %% [markdown]
# # 🟩 커뮤니티 가입 및 게시판 글 관리 프로젝트
# (나중에 SQL 시 써먹을 것이다.)
#
# ## 🔥 생각 좀 잘 하자
# - 실제 db가 없는데...
# - 파일을  > > > >  이런식으로 상속시켜가다보면 당연히 한번 작동이 끝난 파일은 메모리가 당연히 날아가겠지
# - 그렇기 때문에 manager 파일 한 곳에서 실행시키고나면 실행 중인 현재 manager class 내에 저장해놓을 줄 알아야 합니다.
#
#
# ---
# ### 🟢 sign
#
# #### 🟡 회원 - 가입, 조회, 수정, 탈퇴 (본인 정보)
#
# - 회원가입 : 통해 변수에 ID and PW 저장
#   - 여기서 랜덤 회원번호 4자리가 정해지는데...
# - 로그인 : 해당 변수의 ID and PW가 일치한다면 print(로그인에 성공하였습니다.)
# - 나의 개인정보 조회 : 해당 변수 조회
#
# #### 🟡 회원관리 (admin)
#
# (🔥 admin도 별도로 로그인 되어 있어야 합니다. 중복 로그인 될 수 있도록 합시다.)
# (🔥 이거는 그냥 admin 비민번호 입력 시 리스트 print만 해줍시다.)
# (🔥 그렇다면 전역변수로 return 시켜서 매개변수로 받아갈 수 있게 만듭시다. in manager.py)
#
# - 회원번호
# - 회원 아이디
# - 패스워드
# - 이름
# - 전화번호
# - 이메일
#
# ---
#
# ### 🟢 posts
#
# #### 🟡 게시글 작성
#
# - 🔥 글번호 (lan의 +1의 값을 가져가면 됩니다.)
# - 회원번호
# - 작성일 (data 라이브러리 사용) (chatGPT 사용)
# - 제목
# - 내용
# - 🔥 조회수 (함수 실행 카운트?)
#
# #### 🟡 전체 게시글 조회
#
# - <게시판 조회하면 나와야 할 것들>
#   - 🔥 글번호 (lan의 +1의 값을 가져가면 됩니다.)
#   - 작성한 회원번호 (중요)
#   - 작성일
#   - 제목
#   - 내용
#   - 🔥 조회수 (함수 실행 카운트?)
#     (print로 이쁘게 나올 수 있도록 만들어야 합니다.)
#
# #### 🟡 🔥 선택한 게시글 읽기
#
# - 조회수 : 0
# - 수정
# - 삭제
# - 읽어보기
#   - 작성자 (이름 출력)
#   - 제목
#   - 내용
#
#     ##### 🟡 수정
#
#     - (글쓴이만) 회원번호랑 패스워드 입력하면 수정이 가능합니다.
#
#     ##### 🟡 삭제
#
#     - (글쓴이만) 회원번호랑 패스워드 입력하면 삭제가 가능합니다.
