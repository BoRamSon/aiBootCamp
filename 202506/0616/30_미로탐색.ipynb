# %% [markdown]
# # 🟩 미로탐색

# %%
from collections import deque 

#큐를 사용한다. 다음 방문위치를 큐에 넣어놓고 큐에서 빼서 확인하면서 
#탐색하는 방식이다. 동적계획법 너무 고급 
"""
4 6
101111
101010
101011
111011
"""
N, M = map(int, input().split()) 
arr = []
for i in range(N):
    temp = list(input())  # str-> list 
    #print(temp)
    temp = list(map(int, temp))
    arr.append(temp)

def printArray(arr, N):
    for i in range(N):
        print(arr[i])

printArray(arr, N)

visited = [ [-1]*M for _ in range(N) ]



def bfs(y, x): #시작값 y:행, x:열
    dx = [-1,1,0,0]
    dy = [0,0,-1,1]
    visited[y][x] = 1 #방문을했음 
    #bfs는 큐를 활용할 탐색기법이다 
    cnt=0 
    q = deque()
    q.append((y,x)) #튜플로 추가하기 
    while q: #큐가 빌때까지 
        y, x = q.popleft()
        for i in range(len(dy)):
            #새로운좌표만들기; 
            ny = dy[i] + y 
            nx = dx[i] + x 
            if not(0<=nx<M and 0<=ny<N):
                continue 
            if arr[ny][nx]==0:
                continue 
            if visited[ny][nx]==-1:
                visited[ny][nx]=visited[y][x]+1
                #큐에 방금 좌표값 추가 
                q.append((ny, nx))
    return cnt        

def island_count():

    bfs(0,0)
    printArray(visited, N)
    print(visited[N-1][M-1]) 

island_count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       3 #큐를 사용한다. 다음 방문위치를 큐에 넣어놓고 큐에서 빼서 확인하면서
#       4 #탐색하는 방식이다. 동적계획법 너무 고급
#       5 """
#       6 4 6
#       7 101111
#    (...)     10 111011
#      11 """
# ---> 12 N, M = map(int, input().split())
#      13 arr = []
#      14 for i in range(N):
#
# ValueError: invalid literal for int() with base 10: '1,'
